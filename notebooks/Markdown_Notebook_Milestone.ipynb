# %% [markdown]
# # Markdown for Notebooks
#
# This notebook demonstrates how Markdown helps a notebook read like a clear story instead of a loose collection of cells. It uses headings, lists, inline code, and a fenced code block.

# %% [markdown]
# ## What This Notebook Shows
#
# - A logical heading structure
# - An unordered list for key points
# - Inline code such as `customer_id` and `summarize_items()`
# - A fenced code block inside Markdown
# - Short code cells used only to support the explanation

# %%
# Small example values for the notebook narrative
customer_id = 101
items_purchased = ["tea", "cookies", "fruit"]
items_purchased

# %% [markdown]
# ## Step-by-Step Explanation
#
# 1. Define a small piece of data in code.
# 2. Describe what the code means in Markdown.
# 3. Keep the notebook easy to review and reuse.
#
# The variable `items_purchased` stores a simple shopping list for the customer.
#
# ```python
# def summarize_items(items):
#     return len(items)
# ```

# %%
def summarize_items(items):
    return len(items)

total_items = summarize_items(items_purchased)
total_items

# %% [markdown]
# ## Why Markdown Matters
#
# Markdown adds context before code and interpretation after code. That makes the notebook readable for reviewers, teammates, and future you.
#
# If the code works but the purpose is unclear, the missing pieces are usually:
# - weak headings
# - too little explanatory text
# - no lists to structure ideas
# - no inline code or code blocks to clarify syntax
